# %% [markdown]
# The purpose of this notebook is to use the Mountain Project API to collect route data for later analysis. Route IDs are input in batches, and a number of useful features are provided by the API.

# %% [markdown]
# ### Mount Google Drive for file access and storage

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# ### Define functions for data collection

# %%
# credit to github.com/sailskisurf23 for the functions in this cell and a list of route ids

# This script is used to compile a database of useful route features by querying the Mountain Project API.

import requests, random, time, sys, json
from pymongo import MongoClient

# Input file with route ids:
loc_r = '/content/gdrive/My Drive/Python/Mtn_proj_model/data/route_ids.csv'

# Establish output destinations:
client = MongoClient('localhost:27017')
db = client.routesAPI_db

def get_API_routes(route_IDs):
    """
    Returns list of roudids that a given userid has ticked
    Parameters:
    route_IDs: list of str
    Returns:
    routes: list of json str
    """
    time.sleep(2+.5*random.random())
    # build URL
    base_url = 'https://www.mountainproject.com/'
    query_str = 'data/get-routes?'
    route_str = ','.join(route_IDs)
    credfile = '/content/gdrive/My Drive/Python/Mtn_proj_model/mtn_proj_cred_file.txt'
    with open(credfile) as f:
        key = f.read().strip()
    url = base_url + query_str + 'routeIds=' + route_str + '&key=' + key
    # parse json and return 'ticks'
    print('GET routes: {}'.format(route_str))
    r = requests.get(url)
    parsed_json = json.loads(r.content)
    routes = parsed_json['routes']
    return routes

def write_routes_db(routes):
    """
    Writes list of users to database
    Parameters:
    routes: list of json str
    """
    print('writing to db, routes: ', end='')
    for route in routes:
        print('{},'.format(route['id']), end='')
        db.routesAPI_db.insert_one(route)
    print('')
    pass

def chunks(list, n=50):
    """
    Generator function: break list into chunks of len(n)
    """
    for i in range(0, len(list), n):
        yield list[i:i+n]


def get_routes_data():
    # grab routes in chunks
    with open(loc_r) as f:
        routes = [line.strip() for line in f]
    batch_size = 100
    routes_chunks = chunks(routes,batch_size)
    for i,chunk in enumerate(routes_chunks):
        try:
            print('starting chunk {} of {}'.format(i+1,int(len(routes)/batch_size)))
            routes_data = get_API_routes(chunk)
            write_routes_db(routes_data)
        except:
            print('error while retreiving routes: {}'.format(chunk))
            time.sleep(10)

# %% [markdown]
# ### Collect route data using API and save to csv file

# %%
# getRoutes data and store in mongodb
get_routes_data()

# open data in dataframe
routesdb = db.routesAPI_db
df = pd.DataFrame(list(routesdb.find()))

# save data to csv
df.to_csv('/content/gdrive/My Drive/Python/Mtn_proj_model/data/getRoutesData.csv', index=False)

# %% [markdown]
# ### Reload API data as dataframe and initialize new data columns

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import html5lib

# reload data into dataframe
df_r = pd.read_csv('/content/gdrive/My Drive/Python/Mtn_proj_model/data/route_ids.csv', names=['routeid'], dtype='str')

# initialize new columns to be filled by scraping route webpages
df_r['routeName'] = ''
df_r['scoreStars'] = np.nan
df_r['scoreStarsVotes'] = np.nan
df_r['r_type'] = ''
df_r['r_length'] = ''
df_r['FA_data'] = ''
df_r['page_views'] = np.nan
df_r['page_view_rate'] = ''
df_r['desc'] = ''
df_r['locInfo'] = ''
df_r['pro'] = ''
df_r['gradeYDS'] = ''
df_r['gradeFr'] = ''
df_r['gradeEwb'] = ''
df_r['gradeUIAA'] = ''
df_r['gradeZA'] = ''
df_r['gradeBr'] = ''
df_r['commentList'] = ''
df_r['apPopularityScore'] = ''
df_r['apScoreCount'] = ''
df_r['apScoreAvg'] = ''

# %% [markdown]
# ### Reload most recent checkpoint in case of Colab timeout

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import html5lib

# last index of most recently saved csv
last_idx = 60000

# reload dataframe and specify dtypes
df_r = pd.read_csv('/content/gdrive/My Drive/Python/Mtn_proj_model/data/scapedData_0-' + last_idx + '.csv', dtype='str')
df_r['scoreStars'] = pd.to_numeric(df_r['scoreStars'])
df_r['scoreStarsVotes'] = pd.to_numeric(df_r['scoreStarsVotes'])
df_r['page_views'] = pd.to_numeric(df_r['page_views'])

# %% [markdown]
# ### Scrape additional data from route pages, add to dataframe, and save as csv

# %%
# define starting index; in case of colab timeout run above cell first
try: last_idx
except NameError: b = None
if last_idx is not None:
  idx_start = last_idx + 1
else:
  idx_start = 0

# Input file paths:
loc_r = '/content/gdrive/My Drive/Python/Mtn_proj_model/data/route_ids.csv'
base_url = 'https://www.mountainproject.com/'

# create temp dataframe from current row onward; might remove this
df_temp = df_r.loc[idx_start:]

# fill routeid rows with scraped data
for index, row in df_temp.iterrows():

  print('processing index {} of {}'.format(index, len(df_temp)-1))

  try:
    # build URLs
    routeid = row['routeid']
    url = base_url+'route/'+routeid
    # retrieve URLs
    time.sleep(2+random.random())
    r = requests.get(url)
    soup = BeautifulSoup(r.content, 'html5lib')


    # route name
    routeName = soup.find('h1').get_text().strip()

    # collecting this value since it is different than the value from the API, which seems to use 'apScoreCount'
    scoreStarsData = soup.find('span', {'id':'starsWithAvgText-'+str(routeid)}).get_text().replace('\\n','').strip().split(' ')
    scoreStars = scoreStarsData[1]
    scoreStarsVotes = scoreStarsData[3]

    # route type and length; some routes have multiple types (e.g. Trad, Alpine) 
    detail = soup.find('table', {'class':'description-details'}).findChildren('td')
    detail_txt = detail[1].get_text().strip().split(', ')

    r_length = []
    r_type = []
    for item in detail_txt:
      if item[0].isdigit():
        r_length = item
      else:
        r_type.append(item)
    r_type = ', '.join(r_type)

    # FA data
    FA_data = detail[3].get_text().strip().split(', ') # some data has data, some doesn't; sort it out later; will probably not use this data anyway

    # page view and view rate
    page_views = detail[5].get_text().strip().split(' ')[0].replace(',','')
    page_view_rate = detail[5].get_text().strip().split(' ')[-1].replace(',','')

    # description/location/protection info
    desc = []
    locInfo = []
    pro = []
    desc_all = soup.findAll('div', {'class':'fr-view'})
    for item in desc_all:
      if 'Description' in item.previousSibling.previousSibling.get_text(): desc = item.get_text()
      if 'Location' in item.previousSibling.previousSibling.get_text(): locInfo = item.get_text()
      if 'Protection' in item.previousSibling.previousSibling.get_text(): pro = item.get_text()

    # route grades in various formats (collect them all!)
    gradeObj = soup.find('h2', {'class':'inline-block mr-2'}).findChildren('span')
    gradeObjTxt = []
    gradeYDS = []
    gradeFr = []
    gradeEwb = []
    gradeUIAA = []
    gradeZA = []
    gradeBr = []

    for i in range(len(gradeObj)):
      gradeObjTxt.append(gradeObj[i].get_text())

    gradeObjTxt = gradeObjTxt[::2]
    for item in gradeObjTxt:
      if 'YDS' in item: gradeYDS = item.split(' ')[0]
      elif 'French' in item: gradeFr = item.split(' ')[0]
      elif 'Ewbanks' in item: gradeEwb = item.split(' ')[0]
      elif 'UIAA' in item: gradeUIAA = item.split(' ')[0]
      elif 'ZA' in item: gradeZA = item.split(' ')[0]
      elif 'British' in item: gradeBr = item.split(' British')[0]

    # comments
    commentObj = soup.findAll('span', {"class" : 'comment-time'})
    commentList = [item.previousSibling.strip() for item in commentObj]

    # get hidden info (some numbers differ from info shown on page; not sure why)
    extraList = soup.findAll('script')[-1].get_text().split('\n')

    apPopularityScore = []
    apScoreCount = []
    apScoreAvg = []
    for line in extraList:
      if 'apPopularityScore' in line: apPopularityScore = line.strip().split("'")[1]
      if 'apScoreCount' in line: apScoreCount = line.strip().split("'")[1]
      if 'apScoreAvg' in line: apScoreAvg = line.strip().split("'")[1]

    # add scaped values to dataframe
    df_r.at[index, 'routeName'] = routeName
    df_r.at[index, 'scoreStars'] = scoreStars
    df_r.at[index, 'scoreStarsVotes'] = scoreStarsVotes
    df_r.at[index, 'r_type'] = r_type
    df_r.at[index, 'r_length'] = r_length
    df_r.at[index, 'FA_data'] = FA_data
    df_r.at[index, 'page_views'] = page_views
    df_r.at[index, 'page_view_rate'] = page_view_rate
    df_r.at[index, 'desc'] = desc
    df_r.at[index, 'locInfo'] = locInfo
    df_r.at[index, 'pro'] = pro
    df_r.at[index, 'gradeYDS'] = gradeYDS
    df_r.at[index, 'gradeFr'] = gradeFr
    df_r.at[index, 'gradeEwb'] = gradeEwb
    df_r.at[index, 'gradeUIAA'] = gradeUIAA
    df_r.at[index, 'gradeZA'] = gradeZA
    df_r.at[index, 'gradeBr'] = gradeBr
    df_r.at[index, 'commentList'] = commentList
    df_r.at[index, 'apPopularityScore'] = apPopularityScore
    df_r.at[index, 'apScoreCount'] = apScoreCount
    df_r.at[index, 'apScoreAvg'] = apScoreAvg

    # save df every so often in case Colab times out or crashes since disk is non-persistent
    if index % 1000 == 0:
      df_r.to_csv('/content/gdrive/My Drive/Python/Mtn_proj_model/data/scapedData_0-'+str(index)+'.csv', index=False)


  except:
    print('***failed on index # {}'.format(index))
# Out:
# processing index 79501 of 7390
# processing index 79502 of 7390
# processing index 79503 of 7390
# processing index 79504 of 7390
# processing index 79505 of 7390
# processing index 79506 of 7390
# processing index 79507 of 7390
# processing index 79508 of 7390
# processing index 79509 of 7390
# processing index 79510 of 7390
# processing index 79511 of 7390
# processing index 79512 of 7390
# processing index 79513 of 7390
# processing index 79514 of 7390
# processing index 79515 of 7390
# processing index 79516 of 7390
# processing index 79517 of 7390
# processing index 79518 of 7390
# processing index 79519 of 7390
# processing index 79520 of 7390
# processing index 79521 of 7390
# processing index 79522 of 7390
# processing index 79523 of 7390
# processing index 79524 of 7390
# processing index 79525 of 7390
# processing index 79526 of 7390
# processing index 79527 of 7390
# processing index 79528 of 7390
# processing index 79529 of 7390
# processing index 79530 of 7390
# processing index 79531 of 7390
# processing index 79532 of 7390
# processing index 79533 of 7390
# processing index 79534 of 7390
# processing index 79535 of 7390
# processing index 79536 of 7390
# processing index 79537 of 7390
# processing index 79538 of 7390
# processing index 79539 of 7390
# processing index 79540 of 7390
# processing index 79541 of 7390
# processing index 79542 of 7390
# processing index 79543 of 7390
# processing index 79544 of 7390
# processing index 79545 of 7390
# processing index 79546 of 7390
# processing index 79547 of 7390
# processing index 79548 of 7390
# processing index 79549 of 7390
# processing index 79550 of 7390
# processing index 79551 of 7390
# processing index 79552 of 7390
# processing index 79553 of 7390
# processing index 79554 of 7390
# processing index 79555 of 7390
# processing index 79556 of 7390
# processing index 79557 of 7390
# processing index 79558 of 7390
# processing index 79559 of 7390
# processing index 79560 of 7390
# processing index 79561 of 7390
# processing index 79562 of 7390
# processing index 79563 of 7390
# processing index 79564 of 7390
# processing index 79565 of 7390
# processing index 79566 of 7390
# processing index 79567 of 7390
# processing index 79568 of 7390
# processing index 79569 of 7390
# processing index 79570 of 7390
# processing index 79571 of 7390
# processing index 79572 of 7390
# processing index 79573 of 7390
# processing index 79574 of 7390
# processing index 79575 of 7390
# processing index 79576 of 7390
# processing index 79577 of 7390
# processing index 79578 of 7390
# processing index 79579 of 7390
# processing index 79580 of 7390
# processing index 79581 of 7390
# processing index 79582 of 7390
# processing index 79583 of 7390
# processing index 79584 of 7390
# processing index 79585 of 7390
# processing index 79586 of 7390
# processing index 79587 of 7390
# processing index 79588 of 7390
# processing index 79589 of 7390
# processing index 79590 of 7390
# processing index 79591 of 7390
# processing index 79592 of 7390
# processing index 79593 of 7390
# processing index 79594 of 7390
# processing index 79595 of 7390
# processing index 79596 of 7390
# processing index 79597 of 7390
# processing index 79598 of 7390
# processing index 79599 of 7390
# processing index 79600 of 7390
# processing index 79601 of 7390
# processing index 79602 of 7390
# processing index 79603 of 7390
# processing index 79604 of 7390
# processing index 79605 of 7390
# processing index 79606 of 7390
# processing index 79607 of 7390
# processing index 79608 of 7390
# processing index 79609 of 7390
# processing index 79610 of 7390
# processing index 79611 of 7390
# processing index 79612 of 7390
# processing index 79613 of 7390
# processing index 79614 of 7390
# processing index 79615 of 7390
# processing index 79616 of 7390
# processing index 79617 of 7390
# processing index 79618 of 7390
# processing index 79619 of 7390
# processing index 79620 of 7390
# processing index 79621 of 7390
# processing index 79622 of 7390
# processing index 79623 of 7390
# processing index 79624 of 7390
# processing index 79625 of 7390
# processing index 79626 of 7390
# processing index 79627 of 7390
# processing index 79628 of 7390
# processing index 79629 of 7390
# processing index 79630 of 7390
# processing index 79631 of 7390
# processing index 79632 of 7390
# processing index 79633 of 7390
# processing index 79634 of 7390
# processing index 79635 of 7390
# processing index 79636 of 7390
# processing index 79637 of 7390
# processing index 79638 of 7390
# processing index 79639 of 7390
# processing index 79640 of 7390
# processing index 79641 of 7390
# processing index 79642 of 7390
# processing index 79643 of 7390
# processing index 79644 of 7390
# processing index 79645 of 7390
# processing index 79646 of 7390
# processing index 79647 of 7390
# processing index 79648 of 7390
# processing index 79649 of 7390
# processing index 79650 of 7390
# processing index 79651 of 7390
# processing index 79652 of 7390
# processing index 79653 of 7390
# processing index 79654 of 7390
# processing index 79655 of 7390
# processing index 79656 of 7390
# processing index 79657 of 7390
# processing index 79658 of 7390
# processing index 79659 of 7390
# processing index 79660 of 7390
# processing index 79661 of 7390
# processing index 79662 of 7390
# processing index 79663 of 7390
# processing index 79664 of 7390
# processing index 79665 of 7390
# processing index 79666 of 7390
# processing index 79667 of 7390
# processing index 79668 of 7390
# processing index 79669 of 7390
# processing index 79670 of 7390
# processing index 79671 of 7390
# processing index 79672 of 7390
# processing index 79673 of 7390
# processing index 79674 of 7390
# processing index 79675 of 7390
# processing index 79676 of 7390
# processing index 79677 of 7390
# processing index 79678 of 7390
# processing index 79679 of 7390
# processing index 79680 of 7390
# processing index 79681 of 7390
# processing index 79682 of 7390
# processing index 79683 of 7390
# processing index 79684 of 7390
# processing index 79685 of 7390
# ***failed on index # 79685
# processing index 79686 of 7390
# processing index 79687 of 7390
# processing index 79688 of 7390
# processing index 79689 of 7390
# processing index 79690 of 7390
# processing index 79691 of 7390
# processing index 79692 of 7390
# processing index 79693 of 7390
# processing index 79694 of 7390
# processing index 79695 of 7390
# processing index 79696 of 7390
# ***failed on index # 79696
# processing index 79697 of 7390
# processing index 79698 of 7390
# processing index 79699 of 7390
# processing index 79700 of 7390
# processing index 79701 of 7390
# processing index 79702 of 7390
# processing index 79703 of 7390
# processing index 79704 of 7390
# processing index 79705 of 7390
# processing index 79706 of 7390
# processing index 79707 of 7390
# processing index 79708 of 7390
# processing index 79709 of 7390
# processing index 79710 of 7390
# processing index 79711 of 7390
# processing index 79712 of 7390
# processing index 79713 of 7390
# processing index 79714 of 7390
# processing index 79715 of 7390
# processing index 79716 of 7390
# processing index 79717 of 7390
# processing index 79718 of 7390
# processing index 79719 of 7390
# processing index 79720 of 7390
# processing index 79721 of 7390
# processing index 79722 of 7390
# processing index 79723 of 7390
# processing index 79724 of 7390
# processing index 79725 of 7390
# processing index 79726 of 7390
# processing index 79727 of 7390
# processing index 79728 of 7390
# processing index 79729 of 7390
# processing index 79730 of 7390
# processing index 79731 of 7390
# processing index 79732 of 7390
# processing index 79733 of 7390
# processing index 79734 of 7390
# processing index 79735 of 7390
# processing index 79736 of 7390
# processing index 79737 of 7390
# processing index 79738 of 7390
# processing index 79739 of 7390
# processing index 79740 of 7390
# processing index 79741 of 7390
# processing index 79742 of 7390
# processing index 79743 of 7390
# processing index 79744 of 7390
# processing index 79745 of 7390
# processing index 79746 of 7390
# processing index 79747 of 7390
# processing index 79748 of 7390
# processing index 79749 of 7390
# processing index 79750 of 7390
# processing index 79751 of 7390
# processing index 79752 of 7390
# processing index 79753 of 7390
# processing index 79754 of 7390
# processing index 79755 of 7390
# processing index 79756 of 7390
# processing index 79757 of 7390
# processing index 79758 of 7390
# processing index 79759 of 7390
# processing index 79760 of 7390
# processing index 79761 of 7390
# processing index 79762 of 7390
# processing index 79763 of 7390
# processing index 79764 of 7390
# processing index 79765 of 7390
# processing index 79766 of 7390
# processing index 79767 of 7390
# processing index 79768 of 7390
# processing index 79769 of 7390
# processing index 79770 of 7390
# processing index 79771 of 7390
# processing index 79772 of 7390
# processing index 79773 of 7390
# processing index 79774 of 7390
# processing index 79775 of 7390
# processing index 79776 of 7390
# processing index 79777 of 7390
# processing index 79778 of 7390
# processing index 79779 of 7390
# processing index 79780 of 7390
# processing index 79781 of 7390
# processing index 79782 of 7390
# processing index 79783 of 7390
# processing index 79784 of 7390
# processing index 79785 of 7390
# processing index 79786 of 7390
# processing index 79787 of 7390
# processing index 79788 of 7390
# processing index 79789 of 7390
# processing index 79790 of 7390
# processing index 79791 of 7390
# processing index 79792 of 7390
# processing index 79793 of 7390
# processing index 79794 of 7390
# processing index 79795 of 7390
# processing index 79796 of 7390
# processing index 79797 of 7390
# processing index 79798 of 7390
# processing index 79799 of 7390
# processing index 79800 of 7390
# processing index 79801 of 7390
# processing index 79802 of 7390
# processing index 79803 of 7390
# processing index 79804 of 7390
# processing index 79805 of 7390
# processing index 79806 of 7390
# processing index 79807 of 7390
# processing index 79808 of 7390
# processing index 79809 of 7390
# processing index 79810 of 7390
# processing index 79811 of 7390
# processing index 79812 of 7390
# processing index 79813 of 7390
# processing index 79814 of 7390
# processing index 79815 of 7390
# processing index 79816 of 7390
# processing index 79817 of 7390
# processing index 79818 of 7390
# processing index 79819 of 7390
# processing index 79820 of 7390
# processing index 79821 of 7390
# processing index 79822 of 7390
# processing index 79823 of 7390
# processing index 79824 of 7390
# processing index 79825 of 7390
# processing index 79826 of 7390
# processing index 79827 of 7390
# processing index 79828 of 7390
# processing index 79829 of 7390
# processing index 79830 of 7390
# processing index 79831 of 7390
# processing index 79832 of 7390
# processing index 79833 of 7390
# processing index 79834 of 7390
# processing index 79835 of 7390
# processing index 79836 of 7390
# processing index 79837 of 7390
# processing index 79838 of 7390
# processing index 79839 of 7390
# processing index 79840 of 7390
# processing index 79841 of 7390
# processing index 79842 of 7390
# processing index 79843 of 7390
# processing index 79844 of 7390
# processing index 79845 of 7390
# processing index 79846 of 7390
# processing index 79847 of 7390
# processing index 79848 of 7390
# processing index 79849 of 7390
# processing index 79850 of 7390
# processing index 79851 of 7390
# processing index 79852 of 7390
# processing index 79853 of 7390
# processing index 79854 of 7390
# processing index 79855 of 7390
# processing index 79856 of 7390
# processing index 79857 of 7390
# processing index 79858 of 7390
# processing index 79859 of 7390
# processing index 79860 of 7390
# processing index 79861 of 7390
# processing index 79862 of 7390
# processing index 79863 of 7390
# processing index 79864 of 7390
# processing index 79865 of 7390
# processing index 79866 of 7390
# processing index 79867 of 7390
# processing index 79868 of 7390
# processing index 79869 of 7390
# processing index 79870 of 7390
# processing index 79871 of 7390
# processing index 79872 of 7390
# processing index 79873 of 7390
# processing index 79874 of 7390
# processing index 79875 of 7390
# processing index 79876 of 7390
# processing index 79877 of 7390
# processing index 79878 of 7390
# processing index 79879 of 7390
# processing index 79880 of 7390
# processing index 79881 of 7390
# processing index 79882 of 7390
# processing index 79883 of 7390
# processing index 79884 of 7390
# processing index 79885 of 7390
# processing index 79886 of 7390
# processing index 79887 of 7390
# processing index 79888 of 7390
# processing index 79889 of 7390
# processing index 79890 of 7390
# processing index 79891 of 7390
# processing index 79892 of 7390
# processing index 79893 of 7390
# processing index 79894 of 7390
# processing index 79895 of 7390
# processing index 79896 of 7390
# processing index 79897 of 7390
# processing index 79898 of 7390
# processing index 79899 of 7390
# processing index 79900 of 7390
# processing index 79901 of 7390
# processing index 79902 of 7390
# processing index 79903 of 7390
# processing index 79904 of 7390
# processing index 79905 of 7390
# processing index 79906 of 7390
# processing index 79907 of 7390
# processing index 79908 of 7390
# processing index 79909 of 7390
# processing index 79910 of 7390
# processing index 79911 of 7390
# processing index 79912 of 7390
# processing index 79913 of 7390
# processing index 79914 of 7390
# processing index 79915 of 7390
# processing index 79916 of 7390
# processing index 79917 of 7390
# processing index 79918 of 7390
# processing index 79919 of 7390
# processing index 79920 of 7390
# processing index 79921 of 7390
# processing index 79922 of 7390
# processing index 79923 of 7390
# processing index 79924 of 7390
# processing index 79925 of 7390
# processing index 79926 of 7390
# processing index 79927 of 7390
# processing index 79928 of 7390
# processing index 79929 of 7390
# processing index 79930 of 7390
# processing index 79931 of 7390
# processing index 79932 of 7390
# processing index 79933 of 7390
# processing index 79934 of 7390
# processing index 79935 of 7390
# processing index 79936 of 7390
# processing index 79937 of 7390
# processing index 79938 of 7390
# processing index 79939 of 7390
# processing index 79940 of 7390
# processing index 79941 of 7390
# processing index 79942 of 7390
# processing index 79943 of 7390
# processing index 79944 of 7390
# processing index 79945 of 7390
# processing index 79946 of 7390
# processing index 79947 of 7390
# processing index 79948 of 7390
# processing index 79949 of 7390
# processing index 79950 of 7390
# processing index 79951 of 7390
# processing index 79952 of 7390
# processing index 79953 of 7390
# processing index 79954 of 7390
# processing index 79955 of 7390
# processing index 79956 of 7390
# processing index 79957 of 7390
# processing index 79958 of 7390
# processing index 79959 of 7390
# processing index 79960 of 7390
# processing index 79961 of 7390
# processing index 79962 of 7390
# processing index 79963 of 7390
# processing index 79964 of 7390
# processing index 79965 of 7390
# processing index 79966 of 7390
# processing index 79967 of 7390
# processing index 79968 of 7390
# processing index 79969 of 7390
# processing index 79970 of 7390
# processing index 79971 of 7390
# processing index 79972 of 7390
# processing index 79973 of 7390
# processing index 79974 of 7390
# processing index 79975 of 7390
# processing index 79976 of 7390
# processing index 79977 of 7390
# processing index 79978 of 7390
# processing index 79979 of 7390
# processing index 79980 of 7390
# processing index 79981 of 7390
# processing index 79982 of 7390
# processing index 79983 of 7390
# processing index 79984 of 7390
# processing index 79985 of 7390
# processing index 79986 of 7390
# processing index 79987 of 7390
# processing index 79988 of 7390
# processing index 79989 of 7390
# processing index 79990 of 7390
# processing index 79991 of 7390
# processing index 79992 of 7390
# processing index 79993 of 7390
# processing index 79994 of 7390
# processing index 79995 of 7390
# processing index 79996 of 7390
# processing index 79997 of 7390
# processing index 79998 of 7390
# processing index 79999 of 7390
# processing index 80000 of 7390
# processing index 80001 of 7390
# processing index 80002 of 7390
# processing index 80003 of 7390
# processing index 80004 of 7390
# processing index 80005 of 7390
# processing index 80006 of 7390
# processing index 80007 of 7390
# processing index 80008 of 7390
# processing index 80009 of 7390
# processing index 80010 of 7390
# processing index 80011 of 7390
# processing index 80012 of 7390
# processing index 80013 of 7390
# processing index 80014 of 7390
# processing index 80015 of 7390
# processing index 80016 of 7390
# processing index 80017 of 7390
# processing index 80018 of 7390
# processing index 80019 of 7390
# processing index 80020 of 7390
# processing index 80021 of 7390
# processing index 80022 of 7390
# processing index 80023 of 7390
# processing index 80024 of 7390
# processing index 80025 of 7390
# processing index 80026 of 7390
# processing index 80027 of 7390
# processing index 80028 of 7390
# processing index 80029 of 7390
# processing index 80030 of 7390
# processing index 80031 of 7390
# processing index 80032 of 7390
# processing index 80033 of 7390
# processing index 80034 of 7390
# processing index 80035 of 7390
# processing index 80036 of 7390
# processing index 80037 of 7390
# processing index 80038 of 7390
# processing index 80039 of 7390
# processing index 80040 of 7390
# processing index 80041 of 7390
# processing index 80042 of 7390
# processing index 80043 of 7390
# processing index 80044 of 7390
# processing index 80045 of 7390
# processing index 80046 of 7390
# processing index 80047 of 7390
# processing index 80048 of 7390
# processing index 80049 of 7390
# processing index 80050 of 7390
# processing index 80051 of 7390
# processing index 80052 of 7390
# processing index 80053 of 7390
# processing index 80054 of 7390
# processing index 80055 of 7390
# processing index 80056 of 7390
# processing index 80057 of 7390
# processing index 80058 of 7390
# processing index 80059 of 7390
# processing index 80060 of 7390
# processing index 80061 of 7390
# processing index 80062 of 7390
# processing index 80063 of 7390
# processing index 80064 of 7390
# processing index 80065 of 7390
# processing index 80066 of 7390
# processing index 80067 of 7390
# processing index 80068 of 7390
# processing index 80069 of 7390
# processing index 80070 of 7390
# processing index 80071 of 7390
# processing index 80072 of 7390
# processing index 80073 of 7390
# processing index 80074 of 7390
# processing index 80075 of 7390
# processing index 80076 of 7390
# processing index 80077 of 7390
# processing index 80078 of 7390
# processing index 80079 of 7390
# processing index 80080 of 7390
# processing index 80081 of 7390
# processing index 80082 of 7390
# processing index 80083 of 7390
# processing index 80084 of 7390
# processing index 80085 of 7390
# processing index 80086 of 7390
# processing index 80087 of 7390
# processing index 80088 of 7390
# processing index 80089 of 7390
# processing index 80090 of 7390
# processing index 80091 of 7390
# processing index 80092 of 7390
# processing index 80093 of 7390
# processing index 80094 of 7390
# processing index 80095 of 7390
# processing index 80096 of 7390
# processing index 80097 of 7390
# processing index 80098 of 7390
# processing index 80099 of 7390
# processing index 80100 of 7390
# processing index 80101 of 7390
# processing index 80102 of 7390
# processing index 80103 of 7390
# processing index 80104 of 7390
# processing index 80105 of 7390
# processing index 80106 of 7390
# ***failed on index # 80106
# processing index 80107 of 7390
# processing index 80108 of 7390
# processing index 80109 of 7390
# processing index 80110 of 7390
# processing index 80111 of 7390
# processing index 80112 of 7390
# processing index 80113 of 7390
# processing index 80114 of 7390
# processing index 80115 of 7390
# processing index 80116 of 7390
# processing index 80117 of 7390
# processing index 80118 of 7390
# processing index 80119 of 7390
# processing index 80120 of 7390
# processing index 80121 of 7390
# processing index 80122 of 7390
# processing index 80123 of 7390
# processing index 80124 of 7390
# processing index 80125 of 7390
# processing index 80126 of 7390
# processing index 80127 of 7390
# processing index 80128 of 7390
# processing index 80129 of 7390
# processing index 80130 of 7390
# processing index 80131 of 7390
# processing index 80132 of 7390
# processing index 80133 of 7390
# processing index 80134 of 7390
# processing index 80135 of 7390
# processing index 80136 of 7390
# processing index 80137 of 7390
# processing index 80138 of 7390
# processing index 80139 of 7390
# processing index 80140 of 7390
# processing index 80141 of 7390
# processing index 80142 of 7390
# processing index 80143 of 7390
# processing index 80144 of 7390
# processing index 80145 of 7390
# processing index 80146 of 7390
# processing index 80147 of 7390
# processing index 80148 of 7390
# processing index 80149 of 7390
# processing index 80150 of 7390
# processing index 80151 of 7390
# processing index 80152 of 7390
# processing index 80153 of 7390
# processing index 80154 of 7390
# processing index 80155 of 7390
# processing index 80156 of 7390
# processing index 80157 of 7390
# processing index 80158 of 7390
# processing index 80159 of 7390
# processing index 80160 of 7390
# processing index 80161 of 7390
# processing index 80162 of 7390
# processing index 80163 of 7390
# processing index 80164 of 7390
# processing index 80165 of 7390
# processing index 80166 of 7390
# processing index 80167 of 7390
# processing index 80168 of 7390
# processing index 80169 of 7390
# processing index 80170 of 7390
# processing index 80171 of 7390
# processing index 80172 of 7390
# processing index 80173 of 7390
# processing index 80174 of 7390
# processing index 80175 of 7390
# processing index 80176 of 7390
# processing index 80177 of 7390
# processing index 80178 of 7390
# processing index 80179 of 7390
# processing index 80180 of 7390
# processing index 80181 of 7390
# processing index 80182 of 7390
# processing index 80183 of 7390
# processing index 80184 of 7390
# processing index 80185 of 7390
# processing index 80186 of 7390
# processing index 80187 of 7390
# processing index 80188 of 7390
# processing index 80189 of 7390
# processing index 80190 of 7390
# processing index 80191 of 7390
# processing index 80192 of 7390
# processing index 80193 of 7390
# processing index 80194 of 7390
# processing index 80195 of 7390
# processing index 80196 of 7390
# processing index 80197 of 7390
# processing index 80198 of 7390
# processing index 80199 of 7390
# processing index 80200 of 7390
# processing index 80201 of 7390
# processing index 80202 of 7390
# processing index 80203 of 7390
# processing index 80204 of 7390
# processing index 80205 of 7390
# processing index 80206 of 7390
# processing index 80207 of 7390
# processing index 80208 of 7390
# processing index 80209 of 7390
# processing index 80210 of 7390
# processing index 80211 of 7390
# processing index 80212 of 7390
# processing index 80213 of 7390
# processing index 80214 of 7390
# processing index 80215 of 7390
# processing index 80216 of 7390
# processing index 80217 of 7390
# processing index 80218 of 7390
# processing index 80219 of 7390
# processing index 80220 of 7390
# processing index 80221 of 7390
# processing index 80222 of 7390
# processing index 80223 of 7390
# processing index 80224 of 7390
# processing index 80225 of 7390
# processing index 80226 of 7390
# processing index 80227 of 7390
# processing index 80228 of 7390
# processing index 80229 of 7390
# processing index 80230 of 7390
# processing index 80231 of 7390
# processing index 80232 of 7390
# processing index 80233 of 7390
# processing index 80234 of 7390
# processing index 80235 of 7390
# processing index 80236 of 7390
# processing index 80237 of 7390
# processing index 80238 of 7390
# processing index 80239 of 7390
# processing index 80240 of 7390
# processing index 80241 of 7390
# processing index 80242 of 7390
# processing index 80243 of 7390
# processing index 80244 of 7390
# processing index 80245 of 7390
# processing index 80246 of 7390
# processing index 80247 of 7390
# processing index 80248 of 7390
# processing index 80249 of 7390
# processing index 80250 of 7390
# processing index 80251 of 7390
# processing index 80252 of 7390
# processing index 80253 of 7390
# processing index 80254 of 7390
# processing index 80255 of 7390
# processing index 80256 of 7390
# processing index 80257 of 7390
# processing index 80258 of 7390
# processing index 80259 of 7390
# processing index 80260 of 7390
# processing index 80261 of 7390
# processing index 80262 of 7390
# processing index 80263 of 7390
# processing index 80264 of 7390
# processing index 80265 of 7390
# processing index 80266 of 7390
# processing index 80267 of 7390
# processing index 80268 of 7390
# processing index 80269 of 7390
# processing index 80270 of 7390
# processing index 80271 of 7390
# processing index 80272 of 7390
# processing index 80273 of 7390
# processing index 80274 of 7390
# processing index 80275 of 7390
# processing index 80276 of 7390
# processing index 80277 of 7390
# processing index 80278 of 7390
# processing index 80279 of 7390
# processing index 80280 of 7390
# processing index 80281 of 7390
# processing index 80282 of 7390
# processing index 80283 of 7390
# processing index 80284 of 7390
# processing index 80285 of 7390
# processing index 80286 of 7390
# processing index 80287 of 7390
# processing index 80288 of 7390
# processing index 80289 of 7390
# processing index 80290 of 7390
# processing index 80291 of 7390
# processing index 80292 of 7390
# processing index 80293 of 7390
# processing index 80294 of 7390
# processing index 80295 of 7390
# processing index 80296 of 7390
# processing index 80297 of 7390
# processing index 80298 of 7390
# processing index 80299 of 7390
# processing index 80300 of 7390
# processing index 80301 of 7390
# processing index 80302 of 7390
# processing index 80303 of 7390
# processing index 80304 of 7390
# processing index 80305 of 7390
# processing index 80306 of 7390
# processing index 80307 of 7390
# processing index 80308 of 7390
# processing index 80309 of 7390
# processing index 80310 of 7390
# processing index 80311 of 7390
# processing index 80312 of 7390
# processing index 80313 of 7390
# processing index 80314 of 7390
# processing index 80315 of 7390
# processing index 80316 of 7390
# processing index 80317 of 7390
# processing index 80318 of 7390
# processing index 80319 of 7390
# processing index 80320 of 7390
# processing index 80321 of 7390
# processing index 80322 of 7390
# processing index 80323 of 7390
# processing index 80324 of 7390
# processing index 80325 of 7390
# processing index 80326 of 7390
# processing index 80327 of 7390
# processing index 80328 of 7390
# processing index 80329 of 7390
# processing index 80330 of 7390
# processing index 80331 of 7390
# processing index 80332 of 7390
# processing index 80333 of 7390
# processing index 80334 of 7390
# processing index 80335 of 7390
# processing index 80336 of 7390
# processing index 80337 of 7390
# processing index 80338 of 7390
# processing index 80339 of 7390
# processing index 80340 of 7390
# processing index 80341 of 7390
# processing index 80342 of 7390
# processing index 80343 of 7390
# processing index 80344 of 7390
# processing index 80345 of 7390
# processing index 80346 of 7390
# processing index 80347 of 7390
# processing index 80348 of 7390
# processing index 80349 of 7390
# processing index 80350 of 7390
# processing index 80351 of 7390
# processing index 80352 of 7390
# processing index 80353 of 7390
# processing index 80354 of 7390
# processing index 80355 of 7390
# processing index 80356 of 7390
# processing index 80357 of 7390
# processing index 80358 of 7390
# processing index 80359 of 7390
# processing index 80360 of 7390
# processing index 80361 of 7390
# processing index 80362 of 7390
# processing index 80363 of 7390
# processing index 80364 of 7390
# processing index 80365 of 7390
# processing index 80366 of 7390
# processing index 80367 of 7390
# processing index 80368 of 7390
# processing index 80369 of 7390
# processing index 80370 of 7390
# processing index 80371 of 7390
# processing index 80372 of 7390
# processing index 80373 of 7390
# processing index 80374 of 7390
# processing index 80375 of 7390
# processing index 80376 of 7390
# processing index 80377 of 7390
# processing index 80378 of 7390
# processing index 80379 of 7390
# processing index 80380 of 7390
# processing index 80381 of 7390
# processing index 80382 of 7390
# processing index 80383 of 7390
# processing index 80384 of 7390
# processing index 80385 of 7390
# processing index 80386 of 7390
# processing index 80387 of 7390
# processing index 80388 of 7390
# processing index 80389 of 7390
# processing index 80390 of 7390
# processing index 80391 of 7390
# processing index 80392 of 7390
# processing index 80393 of 7390
# processing index 80394 of 7390
# processing index 80395 of 7390
# processing index 80396 of 7390
# processing index 80397 of 7390
# processing index 80398 of 7390
# processing index 80399 of 7390
# processing index 80400 of 7390
# processing index 80401 of 7390
# processing index 80402 of 7390
# processing index 80403 of 7390
# processing index 80404 of 7390
# processing index 80405 of 7390
# processing index 80406 of 7390
# processing index 80407 of 7390
# processing index 80408 of 7390
# processing index 80409 of 7390
# processing index 80410 of 7390
# processing index 80411 of 7390
# processing index 80412 of 7390
# processing index 80413 of 7390
# processing index 80414 of 7390
# processing index 80415 of 7390
# processing index 80416 of 7390
# processing index 80417 of 7390
# processing index 80418 of 7390
# processing index 80419 of 7390
# processing index 80420 of 7390
# processing index 80421 of 7390
# processing index 80422 of 7390
# processing index 80423 of 7390
# processing index 80424 of 7390
# processing index 80425 of 7390
# processing index 80426 of 7390
# processing index 80427 of 7390
# processing index 80428 of 7390
# processing index 80429 of 7390
# processing index 80430 of 7390
# processing index 80431 of 7390
# processing index 80432 of 7390
# processing index 80433 of 7390
# processing index 80434 of 7390
# processing index 80435 of 7390
# processing index 80436 of 7390
# processing index 80437 of 7390
# processing index 80438 of 7390
# processing index 80439 of 7390
# processing index 80440 of 7390
# processing index 80441 of 7390
# processing index 80442 of 7390
# processing index 80443 of 7390
# processing index 80444 of 7390
# processing index 80445 of 7390
# processing index 80446 of 7390
# processing index 80447 of 7390
# processing index 80448 of 7390
# processing index 80449 of 7390
# processing index 80450 of 7390
# processing index 80451 of 7390
# processing index 80452 of 7390
# processing index 80453 of 7390
# processing index 80454 of 7390
# processing index 80455 of 7390
# processing index 80456 of 7390
# processing index 80457 of 7390
# processing index 80458 of 7390
# processing index 80459 of 7390
# processing index 80460 of 7390
# processing index 80461 of 7390
# processing index 80462 of 7390
# processing index 80463 of 7390
# processing index 80464 of 7390
# processing index 80465 of 7390
# processing index 80466 of 7390
# processing index 80467 of 7390
# processing index 80468 of 7390
# processing index 80469 of 7390
# processing index 80470 of 7390
# processing index 80471 of 7390
# processing index 80472 of 7390
# processing index 80473 of 7390
# ***failed on index # 80473
# processing index 80474 of 7390
# processing index 80475 of 7390
# processing index 80476 of 7390
# processing index 80477 of 7390
# processing index 80478 of 7390
# processing index 80479 of 7390
# processing index 80480 of 7390
# processing index 80481 of 7390
# processing index 80482 of 7390
# processing index 80483 of 7390
# processing index 80484 of 7390
# processing index 80485 of 7390
# processing index 80486 of 7390
# processing index 80487 of 7390
# processing index 80488 of 7390
# processing index 80489 of 7390
# processing index 80490 of 7390
# processing index 80491 of 7390
# processing index 80492 of 7390
# processing index 80493 of 7390
# processing index 80494 of 7390
# processing index 80495 of 7390
# processing index 80496 of 7390
# processing index 80497 of 7390
# processing index 80498 of 7390
# processing index 80499 of 7390
# processing index 80500 of 7390
# processing index 80501 of 7390
# processing index 80502 of 7390
# processing index 80503 of 7390
# processing index 80504 of 7390
# processing index 80505 of 7390
# processing index 80506 of 7390
# processing index 80507 of 7390
# processing index 80508 of 7390
# processing index 80509 of 7390
# processing index 80510 of 7390
# processing index 80511 of 7390
# processing index 80512 of 7390
# processing index 80513 of 7390
# processing index 80514 of 7390
# processing index 80515 of 7390
# processing index 80516 of 7390
# processing index 80517 of 7390
# processing index 80518 of 7390
# processing index 80519 of 7390
# processing index 80520 of 7390
# processing index 80521 of 7390
# processing index 80522 of 7390
# processing index 80523 of 7390
# processing index 80524 of 7390
# processing index 80525 of 7390
# processing index 80526 of 7390
# processing index 80527 of 7390
# processing index 80528 of 7390
# processing index 80529 of 7390
# processing index 80530 of 7390
# processing index 80531 of 7390
# processing index 80532 of 7390
# processing index 80533 of 7390
# processing index 80534 of 7390
# processing index 80535 of 7390
# processing index 80536 of 7390
# processing index 80537 of 7390
# processing index 80538 of 7390
# processing index 80539 of 7390
# processing index 80540 of 7390
# processing index 80541 of 7390
# processing index 80542 of 7390
# processing index 80543 of 7390
# processing index 80544 of 7390
# processing index 80545 of 7390
# processing index 80546 of 7390
# processing index 80547 of 7390
# processing index 80548 of 7390
# processing index 80549 of 7390
# processing index 80550 of 7390
# processing index 80551 of 7390
# processing index 80552 of 7390
# processing index 80553 of 7390
# processing index 80554 of 7390
# processing index 80555 of 7390
# processing index 80556 of 7390
# processing index 80557 of 7390
# processing index 80558 of 7390
# processing index 80559 of 7390
# processing index 80560 of 7390
# processing index 80561 of 7390
# processing index 80562 of 7390
# processing index 80563 of 7390
# processing index 80564 of 7390
# processing index 80565 of 7390
# processing index 80566 of 7390
# processing index 80567 of 7390
# processing index 80568 of 7390
# processing index 80569 of 7390
# processing index 80570 of 7390
# processing index 80571 of 7390
# processing index 80572 of 7390
# processing index 80573 of 7390
# processing index 80574 of 7390
# processing index 80575 of 7390
# processing index 80576 of 7390
# processing index 80577 of 7390
# processing index 80578 of 7390
# processing index 80579 of 7390
# processing index 80580 of 7390
# processing index 80581 of 7390
# processing index 80582 of 7390
# processing index 80583 of 7390
# processing index 80584 of 7390
# processing index 80585 of 7390
# processing index 80586 of 7390
# processing index 80587 of 7390
# processing index 80588 of 7390
# processing index 80589 of 7390
# processing index 80590 of 7390
# processing index 80591 of 7390
# processing index 80592 of 7390
# processing index 80593 of 7390
# processing index 80594 of 7390
# processing index 80595 of 7390
# processing index 80596 of 7390
# processing index 80597 of 7390
# processing index 80598 of 7390
# processing index 80599 of 7390
# processing index 80600 of 7390
# processing index 80601 of 7390
# processing index 80602 of 7390
# processing index 80603 of 7390
# processing index 80604 of 7390
# processing index 80605 of 7390
# processing index 80606 of 7390
# processing index 80607 of 7390
# processing index 80608 of 7390
# processing index 80609 of 7390
# processing index 80610 of 7390
# processing index 80611 of 7390
# processing index 80612 of 7390
# processing index 80613 of 7390
# processing index 80614 of 7390
# processing index 80615 of 7390
# processing index 80616 of 7390
# processing index 80617 of 7390
# processing index 80618 of 7390
# processing index 80619 of 7390
# processing index 80620 of 7390
# processing index 80621 of 7390
# processing index 80622 of 7390
# processing index 80623 of 7390
# processing index 80624 of 7390
# processing index 80625 of 7390
# processing index 80626 of 7390
# processing index 80627 of 7390
# processing index 80628 of 7390
# processing index 80629 of 7390
# processing index 80630 of 7390
# processing index 80631 of 7390
# processing index 80632 of 7390
# processing index 80633 of 7390
# processing index 80634 of 7390
# processing index 80635 of 7390
# processing index 80636 of 7390
# processing index 80637 of 7390
# processing index 80638 of 7390
# processing index 80639 of 7390
# processing index 80640 of 7390
# processing index 80641 of 7390
# processing index 80642 of 7390
# processing index 80643 of 7390
# processing index 80644 of 7390
# processing index 80645 of 7390
# processing index 80646 of 7390
# processing index 80647 of 7390
# processing index 80648 of 7390
# processing index 80649 of 7390
# processing index 80650 of 7390
# processing index 80651 of 7390
# processing index 80652 of 7390
# processing index 80653 of 7390
# processing index 80654 of 7390
# processing index 80655 of 7390
# processing index 80656 of 7390
# processing index 80657 of 7390
# processing index 80658 of 7390
# processing index 80659 of 7390
# processing index 80660 of 7390
# processing index 80661 of 7390
# processing index 80662 of 7390
# processing index 80663 of 7390
# processing index 80664 of 7390
# processing index 80665 of 7390
# processing index 80666 of 7390
# processing index 80667 of 7390
# processing index 80668 of 7390
# processing index 80669 of 7390
# processing index 80670 of 7390
# processing index 80671 of 7390
# processing index 80672 of 7390
# processing index 80673 of 7390
# processing index 80674 of 7390
# processing index 80675 of 7390
# processing index 80676 of 7390
# processing index 80677 of 7390
# processing index 80678 of 7390
# processing index 80679 of 7390
# processing index 80680 of 7390
# processing index 80681 of 7390
# processing index 80682 of 7390
# processing index 80683 of 7390
# processing index 80684 of 7390
# processing index 80685 of 7390
# processing index 80686 of 7390
# processing index 80687 of 7390
# processing index 80688 of 7390
# processing index 80689 of 7390
# processing index 80690 of 7390
# processing index 80691 of 7390
# processing index 80692 of 7390
# processing index 80693 of 7390
# processing index 80694 of 7390
# processing index 80695 of 7390
# processing index 80696 of 7390
# processing index 80697 of 7390
# processing index 80698 of 7390
# processing index 80699 of 7390
# processing index 80700 of 7390
# processing index 80701 of 7390
# processing index 80702 of 7390
# processing index 80703 of 7390
# processing index 80704 of 7390
# processing index 80705 of 7390
# processing index 80706 of 7390
# processing index 80707 of 7390
# processing index 80708 of 7390
# processing index 80709 of 7390
# processing index 80710 of 7390
# processing index 80711 of 7390
# processing index 80712 of 7390
# processing index 80713 of 7390
# processing index 80714 of 7390
# processing index 80715 of 7390
# processing index 80716 of 7390
# processing index 80717 of 7390
# processing index 80718 of 7390
# processing index 80719 of 7390
# processing index 80720 of 7390
# processing index 80721 of 7390
# processing index 80722 of 7390
# processing index 80723 of 7390
# processing index 80724 of 7390
# processing index 80725 of 7390
# processing index 80726 of 7390
# processing index 80727 of 7390
# processing index 80728 of 7390
# processing index 80729 of 7390
# processing index 80730 of 7390
# processing index 80731 of 7390
# processing index 80732 of 7390
# processing index 80733 of 7390
# processing index 80734 of 7390
# processing index 80735 of 7390
# processing index 80736 of 7390
# processing index 80737 of 7390
# processing index 80738 of 7390
# processing index 80739 of 7390
# processing index 80740 of 7390
# processing index 80741 of 7390
# processing index 80742 of 7390
# processing index 80743 of 7390
# processing index 80744 of 7390
# processing index 80745 of 7390
# processing index 80746 of 7390
# processing index 80747 of 7390
# processing index 80748 of 7390
# processing index 80749 of 7390
# processing index 80750 of 7390
# processing index 80751 of 7390
# processing index 80752 of 7390
# processing index 80753 of 7390
# processing index 80754 of 7390
# processing index 80755 of 7390
# processing index 80756 of 7390
# processing index 80757 of 7390
# processing index 80758 of 7390
# processing index 80759 of 7390
# processing index 80760 of 7390
# processing index 80761 of 7390
# processing index 80762 of 7390
# processing index 80763 of 7390
# processing index 80764 of 7390
# processing index 80765 of 7390
# processing index 80766 of 7390
# processing index 80767 of 7390
# processing index 80768 of 7390
# processing index 80769 of 7390
# processing index 80770 of 7390
# processing index 80771 of 7390
# processing index 80772 of 7390
# processing index 80773 of 7390
# processing index 80774 of 7390
# processing index 80775 of 7390
# processing index 80776 of 7390
# processing index 80777 of 7390
# processing index 80778 of 7390
# processing index 80779 of 7390
# processing index 80780 of 7390
# processing index 80781 of 7390
# processing index 80782 of 7390
# processing index 80783 of 7390
# processing index 80784 of 7390
# processing index 80785 of 7390
# processing index 80786 of 7390
# processing index 80787 of 7390
# processing index 80788 of 7390
# processing index 80789 of 7390
# processing index 80790 of 7390
# processing index 80791 of 7390
# processing index 80792 of 7390
# processing index 80793 of 7390
# processing index 80794 of 7390
# processing index 80795 of 7390
# processing index 80796 of 7390
# processing index 80797 of 7390
# processing index 80798 of 7390
# processing index 80799 of 7390
# processing index 80800 of 7390
# processing index 80801 of 7390
# processing index 80802 of 7390
# processing index 80803 of 7390
# processing index 80804 of 7390
# processing index 80805 of 7390
# processing index 80806 of 7390
# processing index 80807 of 7390
# processing index 80808 of 7390
# processing index 80809 of 7390
# processing index 80810 of 7390
# processing index 80811 of 7390
# processing index 80812 of 7390
# processing index 80813 of 7390
# processing index 80814 of 7390
# processing index 80815 of 7390
# processing index 80816 of 7390
# processing index 80817 of 7390
# processing index 80818 of 7390
# processing index 80819 of 7390
# processing index 80820 of 7390
# processing index 80821 of 7390
# processing index 80822 of 7390
# processing index 80823 of 7390
# processing index 80824 of 7390
# processing index 80825 of 7390
# processing index 80826 of 7390
# processing index 80827 of 7390
# processing index 80828 of 7390
# processing index 80829 of 7390
# processing index 80830 of 7390
# processing index 80831 of 7390
# processing index 80832 of 7390
# processing index 80833 of 7390
# processing index 80834 of 7390
# processing index 80835 of 7390
# processing index 80836 of 7390
# processing index 80837 of 7390
# processing index 80838 of 7390
# processing index 80839 of 7390
# processing index 80840 of 7390
# processing index 80841 of 7390
# processing index 80842 of 7390
# processing index 80843 of 7390
# processing index 80844 of 7390
# processing index 80845 of 7390
# processing index 80846 of 7390
# processing index 80847 of 7390
# processing index 80848 of 7390
# processing index 80849 of 7390
# processing index 80850 of 7390
# processing index 80851 of 7390
# processing index 80852 of 7390
# processing index 80853 of 7390
# processing index 80854 of 7390
# processing index 80855 of 7390
# processing index 80856 of 7390
# processing index 80857 of 7390
# processing index 80858 of 7390
# processing index 80859 of 7390
# processing index 80860 of 7390
# processing index 80861 of 7390
# processing index 80862 of 7390
# processing index 80863 of 7390
# processing index 80864 of 7390
# processing index 80865 of 7390
# processing index 80866 of 7390
# processing index 80867 of 7390
# processing index 80868 of 7390
# processing index 80869 of 7390
# processing index 80870 of 7390
# processing index 80871 of 7390
# processing index 80872 of 7390
# processing index 80873 of 7390
# processing index 80874 of 7390
# processing index 80875 of 7390
# processing index 80876 of 7390
# processing index 80877 of 7390
# processing index 80878 of 7390
# processing index 80879 of 7390
# processing index 80880 of 7390
# processing index 80881 of 7390
# processing index 80882 of 7390
# processing index 80883 of 7390
# processing index 80884 of 7390
# processing index 80885 of 7390
# processing index 80886 of 7390
# processing index 80887 of 7390
# processing index 80888 of 7390
# processing index 80889 of 7390
# processing index 80890 of 7390
# processing index 80891 of 7390
# processing index 80892 of 7390
# processing index 80893 of 7390
# processing index 80894 of 7390
# processing index 80895 of 7390
# processing index 80896 of 7390
# processing index 80897 of 7390
# processing index 80898 of 7390
# processing index 80899 of 7390
# processing index 80900 of 7390
# processing index 80901 of 7390
# processing index 80902 of 7390
# processing index 80903 of 7390
# processing index 80904 of 7390
# processing index 80905 of 7390
# processing index 80906 of 7390
# processing index 80907 of 7390
# processing index 80908 of 7390
# processing index 80909 of 7390
# processing index 80910 of 7390
# processing index 80911 of 7390
# processing index 80912 of 7390
# processing index 80913 of 7390
# processing index 80914 of 7390
# processing index 80915 of 7390
# processing index 80916 of 7390
# processing index 80917 of 7390
# processing index 80918 of 7390
# processing index 80919 of 7390
# processing index 80920 of 7390
# processing index 80921 of 7390
# processing index 80922 of 7390
# processing index 80923 of 7390
# processing index 80924 of 7390
# processing index 80925 of 7390
# processing index 80926 of 7390
# processing index 80927 of 7390
# processing index 80928 of 7390
# processing index 80929 of 7390
# processing index 80930 of 7390
# processing index 80931 of 7390
# processing index 80932 of 7390
# processing index 80933 of 7390
# processing index 80934 of 7390
# processing index 80935 of 7390
# processing index 80936 of 7390
# processing index 80937 of 7390
# processing index 80938 of 7390
# processing index 80939 of 7390
# processing index 80940 of 7390
# processing index 80941 of 7390
# processing index 80942 of 7390
# processing index 80943 of 7390
# processing index 80944 of 7390
# processing index 80945 of 7390
# processing index 80946 of 7390
# processing index 80947 of 7390
# processing index 80948 of 7390
# processing index 80949 of 7390
# processing index 80950 of 7390
# processing index 80951 of 7390
# processing index 80952 of 7390
# processing index 80953 of 7390
# processing index 80954 of 7390
# processing index 80955 of 7390
# processing index 80956 of 7390
# processing index 80957 of 7390
# processing index 80958 of 7390
# processing index 80959 of 7390
# processing index 80960 of 7390
# processing index 80961 of 7390
# processing index 80962 of 7390
# processing index 80963 of 7390
# processing index 80964 of 7390
# processing index 80965 of 7390
# processing index 80966 of 7390
# processing index 80967 of 7390
# processing index 80968 of 7390
# processing index 80969 of 7390
# processing index 80970 of 7390
# processing index 80971 of 7390
# processing index 80972 of 7390
# processing index 80973 of 7390
# processing index 80974 of 7390
# processing index 80975 of 7390
# processing index 80976 of 7390
# processing index 80977 of 7390
# processing index 80978 of 7390
# processing index 80979 of 7390
# processing index 80980 of 7390
# processing index 80981 of 7390
# processing index 80982 of 7390
# processing index 80983 of 7390
# processing index 80984 of 7390
# processing index 80985 of 7390
# processing index 80986 of 7390
# processing index 80987 of 7390
# processing index 80988 of 7390
# processing index 80989 of 7390
# processing index 80990 of 7390
# processing index 80991 of 7390
# processing index 80992 of 7390
# processing index 80993 of 7390
# processing index 80994 of 7390
# processing index 80995 of 7390
# processing index 80996 of 7390
# processing index 80997 of 7390
# processing index 80998 of 7390
# processing index 80999 of 7390
# processing index 81000 of 7390
# processing index 81001 of 7390
# processing index 81002 of 7390
# processing index 81003 of 7390
# processing index 81004 of 7390
# processing index 81005 of 7390
# processing index 81006 of 7390
# processing index 81007 of 7390
# processing index 81008 of 7390
# processing index 81009 of 7390
# processing index 81010 of 7390
# processing index 81011 of 7390
# processing index 81012 of 7390
# processing index 81013 of 7390
# processing index 81014 of 7390
# processing index 81015 of 7390
# processing index 81016 of 7390
# processing index 81017 of 7390
# processing index 81018 of 7390
# processing index 81019 of 7390
# processing index 81020 of 7390
# processing index 81021 of 7390
# processing index 81022 of 7390
# processing index 81023 of 7390
# processing index 81024 of 7390
# processing index 81025 of 7390
# processing index 81026 of 7390
# processing index 81027 of 7390
# processing index 81028 of 7390
# processing index 81029 of 7390
# processing index 81030 of 7390
# processing index 81031 of 7390
# processing index 81032 of 7390
# processing index 81033 of 7390
# processing index 81034 of 7390
# processing index 81035 of 7390
# processing index 81036 of 7390
# processing index 81037 of 7390
# processing index 81038 of 7390
# processing index 81039 of 7390
# processing index 81040 of 7390
# processing index 81041 of 7390
# processing index 81042 of 7390
# processing index 81043 of 7390
# processing index 81044 of 7390
# ...
# processing index 86376 of 7390
# processing index 86377 of 7390
# processing index 86378 of 7390
# processing index 86379 of 7390
# processing index 86380 of 7390
# processing index 86381 of 7390
# processing index 86382 of 7390
# processing index 86383 of 7390
# processing index 86384 of 7390
# processing index 86385 of 7390
# processing index 86386 of 7390
# processing index 86387 of 7390
# processing index 86388 of 7390
# processing index 86389 of 7390
# processing index 86390 of 7390
# processing index 86391 of 7390
# processing index 86392 of 7390
# processing index 86393 of 7390
# processing index 86394 of 7390
# processing index 86395 of 7390
# processing index 86396 of 7390
# processing index 86397 of 7390
# processing index 86398 of 7390
# processing index 86399 of 7390
# processing index 86400 of 7390
# processing index 86401 of 7390
# processing index 86402 of 7390
# processing index 86403 of 7390
# processing index 86404 of 7390
# processing index 86405 of 7390
# processing index 86406 of 7390
# processing index 86407 of 7390
# processing index 86408 of 7390
# processing index 86409 of 7390
# processing index 86410 of 7390
# processing index 86411 of 7390
# processing index 86412 of 7390
# processing index 86413 of 7390
# processing index 86414 of 7390
# processing index 86415 of 7390
# processing index 86416 of 7390
# processing index 86417 of 7390
# processing index 86418 of 7390
# processing index 86419 of 7390
# processing index 86420 of 7390
# processing index 86421 of 7390
# processing index 86422 of 7390
# processing index 86423 of 7390
# processing index 86424 of 7390
# processing index 86425 of 7390
# processing index 86426 of 7390
# processing index 86427 of 7390
# processing index 86428 of 7390
# processing index 86429 of 7390
# processing index 86430 of 7390
# processing index 86431 of 7390
# processing index 86432 of 7390
# processing index 86433 of 7390
# processing index 86434 of 7390
# processing index 86435 of 7390
# processing index 86436 of 7390
# processing index 86437 of 7390
# processing index 86438 of 7390
# processing index 86439 of 7390
# processing index 86440 of 7390
# processing index 86441 of 7390
# processing index 86442 of 7390
# processing index 86443 of 7390
# processing index 86444 of 7390
# processing index 86445 of 7390
# processing index 86446 of 7390
# processing index 86447 of 7390
# processing index 86448 of 7390
# processing index 86449 of 7390
# processing index 86450 of 7390
# processing index 86451 of 7390
# processing index 86452 of 7390
# processing index 86453 of 7390
# processing index 86454 of 7390
# processing index 86455 of 7390
# processing index 86456 of 7390
# processing index 86457 of 7390
# processing index 86458 of 7390
# processing index 86459 of 7390
# processing index 86460 of 7390
# processing index 86461 of 7390
# processing index 86462 of 7390
# processing index 86463 of 7390
# processing index 86464 of 7390
# processing index 86465 of 7390
# processing index 86466 of 7390
# processing index 86467 of 7390
# processing index 86468 of 7390
# processing index 86469 of 7390
# processing index 86470 of 7390
# processing index 86471 of 7390
# processing index 86472 of 7390
# processing index 86473 of 7390
# processing index 86474 of 7390
# processing index 86475 of 7390
# processing index 86476 of 7390
# processing index 86477 of 7390
# processing index 86478 of 7390
# processing index 86479 of 7390
# processing index 86480 of 7390
# processing index 86481 of 7390
# processing index 86482 of 7390
# processing index 86483 of 7390
# processing index 86484 of 7390
# processing index 86485 of 7390
# processing index 86486 of 7390
# processing index 86487 of 7390
# processing index 86488 of 7390
# processing index 86489 of 7390
# processing index 86490 of 7390
# processing index 86491 of 7390
# processing index 86492 of 7390
# processing index 86493 of 7390
# processing index 86494 of 7390
# processing index 86495 of 7390
# processing index 86496 of 7390
# processing index 86497 of 7390
# processing index 86498 of 7390
# processing index 86499 of 7390
# processing index 86500 of 7390
# processing index 86501 of 7390
# processing index 86502 of 7390
# processing index 86503 of 7390
# processing index 86504 of 7390
# processing index 86505 of 7390
# processing index 86506 of 7390
# processing index 86507 of 7390
# processing index 86508 of 7390
# processing index 86509 of 7390
# processing index 86510 of 7390
# processing index 86511 of 7390
# processing index 86512 of 7390
# processing index 86513 of 7390
# processing index 86514 of 7390
# processing index 86515 of 7390
# processing index 86516 of 7390
# processing index 86517 of 7390
# processing index 86518 of 7390
# processing index 86519 of 7390
# processing index 86520 of 7390
# processing index 86521 of 7390
# processing index 86522 of 7390
# processing index 86523 of 7390
# processing index 86524 of 7390
# processing index 86525 of 7390
# processing index 86526 of 7390
# processing index 86527 of 7390
# processing index 86528 of 7390
# processing index 86529 of 7390
# processing index 86530 of 7390
# processing index 86531 of 7390
# processing index 86532 of 7390
# processing index 86533 of 7390
# processing index 86534 of 7390
# processing index 86535 of 7390
# processing index 86536 of 7390
# processing index 86537 of 7390
# processing index 86538 of 7390
# processing index 86539 of 7390
# processing index 86540 of 7390
# processing index 86541 of 7390
# processing index 86542 of 7390
# processing index 86543 of 7390
# processing index 86544 of 7390
# processing index 86545 of 7390
# processing index 86546 of 7390
# processing index 86547 of 7390
# processing index 86548 of 7390
# processing index 86549 of 7390
# processing index 86550 of 7390
# processing index 86551 of 7390
# processing index 86552 of 7390
# processing index 86553 of 7390
# processing index 86554 of 7390
# processing index 86555 of 7390
# processing index 86556 of 7390
# processing index 86557 of 7390
# processing index 86558 of 7390
# processing index 86559 of 7390
# processing index 86560 of 7390
# processing index 86561 of 7390
# processing index 86562 of 7390
# processing index 86563 of 7390
# processing index 86564 of 7390
# processing index 86565 of 7390
# processing index 86566 of 7390
# processing index 86567 of 7390
# processing index 86568 of 7390
# processing index 86569 of 7390
# processing index 86570 of 7390
# processing index 86571 of 7390
# processing index 86572 of 7390
# processing index 86573 of 7390
# processing index 86574 of 7390
# processing index 86575 of 7390
# processing index 86576 of 7390
# processing index 86577 of 7390
# processing index 86578 of 7390
# processing index 86579 of 7390
# processing index 86580 of 7390
# processing index 86581 of 7390
# processing index 86582 of 7390
# processing index 86583 of 7390
# processing index 86584 of 7390
# processing index 86585 of 7390
# processing index 86586 of 7390
# processing index 86587 of 7390
# processing index 86588 of 7390
# processing index 86589 of 7390
# processing index 86590 of 7390
# processing index 86591 of 7390
# processing index 86592 of 7390
# processing index 86593 of 7390
# processing index 86594 of 7390
# processing index 86595 of 7390
# processing index 86596 of 7390
# processing index 86597 of 7390
# processing index 86598 of 7390
# processing index 86599 of 7390
# processing index 86600 of 7390
# processing index 86601 of 7390
# processing index 86602 of 7390
# processing index 86603 of 7390
# processing index 86604 of 7390
# processing index 86605 of 7390
# processing index 86606 of 7390
# processing index 86607 of 7390
# processing index 86608 of 7390
# processing index 86609 of 7390
# processing index 86610 of 7390
# processing index 86611 of 7390
# processing index 86612 of 7390
# processing index 86613 of 7390
# processing index 86614 of 7390
# processing index 86615 of 7390
# processing index 86616 of 7390
# processing index 86617 of 7390
# processing index 86618 of 7390
# processing index 86619 of 7390
# processing index 86620 of 7390
# processing index 86621 of 7390
# processing index 86622 of 7390
# processing index 86623 of 7390
# processing index 86624 of 7390
# processing index 86625 of 7390
# processing index 86626 of 7390
# processing index 86627 of 7390
# processing index 86628 of 7390
# processing index 86629 of 7390
# processing index 86630 of 7390
# processing index 86631 of 7390
# processing index 86632 of 7390
# processing index 86633 of 7390
# processing index 86634 of 7390
# processing index 86635 of 7390
# processing index 86636 of 7390
# processing index 86637 of 7390
# processing index 86638 of 7390
# processing index 86639 of 7390
# processing index 86640 of 7390
# processing index 86641 of 7390
# processing index 86642 of 7390
# processing index 86643 of 7390
# processing index 86644 of 7390
# processing index 86645 of 7390
# processing index 86646 of 7390
# processing index 86647 of 7390
# processing index 86648 of 7390
# processing index 86649 of 7390
# processing index 86650 of 7390
# processing index 86651 of 7390
# processing index 86652 of 7390
# processing index 86653 of 7390
# processing index 86654 of 7390
# processing index 86655 of 7390
# processing index 86656 of 7390
# processing index 86657 of 7390
# processing index 86658 of 7390
# processing index 86659 of 7390
# processing index 86660 of 7390
# processing index 86661 of 7390
# processing index 86662 of 7390
# processing index 86663 of 7390
# processing index 86664 of 7390
# processing index 86665 of 7390
# processing index 86666 of 7390
# processing index 86667 of 7390
# processing index 86668 of 7390
# processing index 86669 of 7390
# processing index 86670 of 7390
# processing index 86671 of 7390
# processing index 86672 of 7390
# processing index 86673 of 7390
# processing index 86674 of 7390
# processing index 86675 of 7390
# processing index 86676 of 7390
# processing index 86677 of 7390
# processing index 86678 of 7390
# processing index 86679 of 7390
# processing index 86680 of 7390
# processing index 86681 of 7390
# processing index 86682 of 7390
# processing index 86683 of 7390
# processing index 86684 of 7390
# processing index 86685 of 7390
# processing index 86686 of 7390
# processing index 86687 of 7390
# processing index 86688 of 7390
# processing index 86689 of 7390
# processing index 86690 of 7390
# processing index 86691 of 7390
# processing index 86692 of 7390
# processing index 86693 of 7390
# processing index 86694 of 7390
# processing index 86695 of 7390
# processing index 86696 of 7390
# processing index 86697 of 7390
# processing index 86698 of 7390
# processing index 86699 of 7390
# processing index 86700 of 7390
# processing index 86701 of 7390
# processing index 86702 of 7390
# processing index 86703 of 7390
# processing index 86704 of 7390
# processing index 86705 of 7390
# processing index 86706 of 7390
# processing index 86707 of 7390
# processing index 86708 of 7390
# processing index 86709 of 7390
# processing index 86710 of 7390
# processing index 86711 of 7390
# processing index 86712 of 7390
# processing index 86713 of 7390
# processing index 86714 of 7390
# processing index 86715 of 7390
# processing index 86716 of 7390
# processing index 86717 of 7390
# processing index 86718 of 7390
# processing index 86719 of 7390
# processing index 86720 of 7390
# processing index 86721 of 7390
# processing index 86722 of 7390
# processing index 86723 of 7390
# processing index 86724 of 7390
# processing index 86725 of 7390
# processing index 86726 of 7390
# processing index 86727 of 7390
# processing index 86728 of 7390
# processing index 86729 of 7390
# processing index 86730 of 7390
# processing index 86731 of 7390
# processing index 86732 of 7390
# processing index 86733 of 7390
# processing index 86734 of 7390
# processing index 86735 of 7390
# processing index 86736 of 7390
# processing index 86737 of 7390
# processing index 86738 of 7390
# processing index 86739 of 7390
# processing index 86740 of 7390
# processing index 86741 of 7390
# processing index 86742 of 7390
# processing index 86743 of 7390
# processing index 86744 of 7390
# processing index 86745 of 7390
# processing index 86746 of 7390
# processing index 86747 of 7390
# processing index 86748 of 7390
# processing index 86749 of 7390
# processing index 86750 of 7390
# processing index 86751 of 7390
# processing index 86752 of 7390
# processing index 86753 of 7390
# processing index 86754 of 7390
# processing index 86755 of 7390
# processing index 86756 of 7390
# processing index 86757 of 7390
# processing index 86758 of 7390
# processing index 86759 of 7390
# processing index 86760 of 7390
# processing index 86761 of 7390
# processing index 86762 of 7390
# processing index 86763 of 7390
# processing index 86764 of 7390
# processing index 86765 of 7390
# processing index 86766 of 7390
# processing index 86767 of 7390
# processing index 86768 of 7390
# processing index 86769 of 7390
# processing index 86770 of 7390
# processing index 86771 of 7390
# processing index 86772 of 7390
# processing index 86773 of 7390
# processing index 86774 of 7390
# processing index 86775 of 7390
# processing index 86776 of 7390
# processing index 86777 of 7390
# processing index 86778 of 7390
# processing index 86779 of 7390
# processing index 86780 of 7390
# processing index 86781 of 7390
# processing index 86782 of 7390
# processing index 86783 of 7390
# processing index 86784 of 7390
# processing index 86785 of 7390
# processing index 86786 of 7390
# processing index 86787 of 7390
# processing index 86788 of 7390
# processing index 86789 of 7390
# processing index 86790 of 7390
# processing index 86791 of 7390
# processing index 86792 of 7390
# processing index 86793 of 7390
# processing index 86794 of 7390
# processing index 86795 of 7390
# processing index 86796 of 7390
# processing index 86797 of 7390
# processing index 86798 of 7390
# processing index 86799 of 7390
# processing index 86800 of 7390
# processing index 86801 of 7390
# processing index 86802 of 7390
# processing index 86803 of 7390
# processing index 86804 of 7390
# processing index 86805 of 7390
# processing index 86806 of 7390
# processing index 86807 of 7390
# processing index 86808 of 7390
# processing index 86809 of 7390
# processing index 86810 of 7390
# processing index 86811 of 7390
# processing index 86812 of 7390
# processing index 86813 of 7390
# processing index 86814 of 7390
# processing index 86815 of 7390
# processing index 86816 of 7390
# processing index 86817 of 7390
# processing index 86818 of 7390
# processing index 86819 of 7390
# processing index 86820 of 7390
# processing index 86821 of 7390
# processing index 86822 of 7390
# processing index 86823 of 7390
# processing index 86824 of 7390
# processing index 86825 of 7390
# processing index 86826 of 7390
# processing index 86827 of 7390
# processing index 86828 of 7390
# processing index 86829 of 7390
# processing index 86830 of 7390
# processing index 86831 of 7390
# processing index 86832 of 7390
# processing index 86833 of 7390
# processing index 86834 of 7390
# processing index 86835 of 7390
# processing index 86836 of 7390
# processing index 86837 of 7390
# processing index 86838 of 7390
# processing index 86839 of 7390
# processing index 86840 of 7390
# processing index 86841 of 7390
# processing index 86842 of 7390
# processing index 86843 of 7390
# processing index 86844 of 7390
# processing index 86845 of 7390
# processing index 86846 of 7390
# processing index 86847 of 7390
# processing index 86848 of 7390
# processing index 86849 of 7390
# processing index 86850 of 7390
# processing index 86851 of 7390
# processing index 86852 of 7390
# processing index 86853 of 7390
# processing index 86854 of 7390
# processing index 86855 of 7390
# processing index 86856 of 7390
# processing index 86857 of 7390
# processing index 86858 of 7390
# processing index 86859 of 7390
# processing index 86860 of 7390
# processing index 86861 of 7390
# processing index 86862 of 7390
# processing index 86863 of 7390
# processing index 86864 of 7390
# processing index 86865 of 7390
# processing index 86866 of 7390
# processing index 86867 of 7390
# processing index 86868 of 7390
# processing index 86869 of 7390
# processing index 86870 of 7390
# processing index 86871 of 7390
# processing index 86872 of 7390
# processing index 86873 of 7390
# processing index 86874 of 7390
# processing index 86875 of 7390
# processing index 86876 of 7390
# processing index 86877 of 7390
# processing index 86878 of 7390
# processing index 86879 of 7390
# processing index 86880 of 7390
# processing index 86881 of 7390
# processing index 86882 of 7390
# processing index 86883 of 7390
# processing index 86884 of 7390
# processing index 86885 of 7390
# processing index 86886 of 7390
# processing index 86887 of 7390
# processing index 86888 of 7390
# processing index 86889 of 7390
# processing index 86890 of 7390
# processing index 86891 of 7390
